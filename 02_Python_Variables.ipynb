# %% [markdown]
# <a href="https://colab.research.google.com/github/mariafernandamr/MariaFernanda-DataVisualization2023/blob/main/02_Python_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. What is a variable?**
#
# A variable is a `container`, in the sense that it *stores* values.

# %% [markdown]
# # **2. Declaration**

# %%
# Example

a = 2.57
print(a)
# Out:
# 2.57

# %%
#Example
num = 3.14195687246
pi  = 0
pf  = 7

print('The approximation of',num, 'with:')
print('Decimals','Result')
for i in range(pi,pf+1): 
  print(i, '\t', round(num,i))
# Out:
# The approximation of 3.14195687246 with:
# Decimals Result
# 0 	 3.0
# 1 	 3.1
# 2 	 3.14
# 3 	 3.142
# 4 	 3.142
# 5 	 3.14196
# 6 	 3.141957
# 7 	 3.1419569

# %%
# Example

x = y = z = 45
print(x,y,z)
# Out:
# 45 45 45

# %%
# Example - replace values

z = 17

# %% [markdown]
# # **3. Delete and Clear**

# %%
# Example - delete

del x, y

# %%
# Example - clear

# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# # **4. Naming**

# %% [markdown]
# ## 4.1. Conditions and restrictions

# %%
# Example - always a name of variable must start with a letter

age = 18

# %% [markdown]
# ## 4.2. Best practices
#
# * Case sensitive

# %%
# Example

Age = 78
AGE = 23

# Sug: always use lower case.

# %% [markdown]
# * Compound names

# %%
# Example

price_jean = 150000

# %% [markdown]
# # **5. Data types**

# %% [markdown]
# ## 5.1. Integers

# %% [markdown]
# ## 5.2. Float

# %% [markdown]
# **Parenthesis**: A trick

# %%
# Example -set up

w = 0

# %%
# Example

w += -2
print(w)
# Out:
# -4

# %% [markdown]
# ## 5.3. Strings

# %%
# Example

name = 'Universidad de La Salle'
print(name)
# Out:
# Universidad de La Salle

# %%
name[-2]
# Out:
# 'l'

# %%
name[0:11]
# Out:
# 'Universidad'

# %%
name.split()[0]
# Out:
# 'Universidad'

# %% [markdown]
# ## 5.4. Booleans

# %% [markdown]
# These strings variables but whit a very specific text: **True** or **False**

# %%
# Example

raining = True
daytime = False
raining = daytime

# %% [markdown]
# **BOOLEAN EXPRESSIONS**

# %%
# Example

x = 5 
y = 7 

print('is x less equal to y?' , x == y)
print('is x less than  y?' , x < y)
print('is x greater than y?' , x > y)
print('is x NOT equal y?' , x != y)
# Out:
# is x less equal to y? False
# is x less than  y? True
# is x greater than y? False
# is x NOT equal y? True

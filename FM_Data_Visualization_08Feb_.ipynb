# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernandamoz/FM_23/blob/main/FM_Data_Visualization_08Feb_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Title
# ##Subtitle
# ###Subsubtitle

# %% [markdown]
# #Subsection 1

# %% [markdown]
# #Bold
#
# thong **
#
# **Fernanda**
#
# # italic
#
# *Fernanda* = Fernanda
#
# #Bold
# **Maria Fernanda Mozo Rodriguez**
#
# **Maria Fernanda**
#
# # italic
# *Mozo*
#
# ***Rodriguez***
#
#
#
# #Unordered List
# **Best Singers**
#
# 1. Justin Bieber
# 2. Maluma
# 3. Adele

# %% [markdown]
# # Nested list
#
# **To-Do list:**
# 1. Training
#
#   1.1. Wake-up early
#
#   1.2. Run 10 kms
#
# 2. Rest
#
#   2.1. Sleep

# %% [markdown]
# #Nested List
#
# 1. **Morning**
#
#   1.1. Wake-up early
#
#   1.2. Take a shower
#
#   1.3. Eat Breaskfast
#
#   1.4. Feed my pets
#
#   1.5. Class
#
# 2. **Afternoon**
#
#   2.1 Make my lunch
#
#   2.2 Work
#
#   2.3 Listen music
#
# 3. **Night**
#
#   3.1. Skincare
#
#   3.2 Dinnner
#
#   3.3 Drink a tea
#
#   3.4 Sleep

# %% [markdown]
# #Insert
#
# [La Salle](https://www.lasalle.edu.co/)

# %% [markdown]
# #Insert an Image
#
# ![_107317867_gettyimages-485916302.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Tables
#
# | a | b | c |
# |---|---|---|
#
#
#
# |Name|Age|Relationship|
# |---|---|---|
# |Monica|24|Friend
# |Lina|23|Friend
# |Juan|25|Boyfriend
# |Dora|26|Mother
# |Laura|22|Sister
